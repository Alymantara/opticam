# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
w1,f1 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/old_data/Opticam_qe.data.old',unpack=True)
w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/Opticam_qe.data',unpack=True)

# %%
plt.plot(w1,f1)
plt.plot(w2,f2)

# %%
w1,f1 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/rprime_filter.data',unpack=True)
w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/old_data/rprime_filter.data',unpack=True)

# %%
plt.plot(w1,f1)
plt.plot(w2,f2)

# %%
w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/astrodon_gen2_filtre_u.txt',unpack=True)
idx   = np.argsort(w2)
w2 = np.array(w2)[idx]
f2 = np.array(f2)[idx]
np.savetxt('APOExptime/data/spm2_1m/Opticam/uprime_filter.data',np.array([w2*10,np.abs(f2)]).T,fmt='%5.0f %8.4f')

w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/astrodon_gen2_filtre_g.txt',unpack=True)
idx   = np.argsort(w2)
w2 = np.array(w2)[idx]
f2 = np.array(f2)[idx]
np.savetxt('APOExptime/data/spm2_1m/Opticam/gprime_filter.data',np.array([w2*10,np.abs(f2)]).T,fmt='%5.0f %8.4f')

w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/astrodon_gen2_filtre_r.txt',unpack=True)
idx   = np.argsort(w2)
w2 = np.array(w2)[idx]
f2 = np.array(f2)[idx]
np.savetxt('APOExptime/data/spm2_1m/Opticam/rprime_filter.data',np.array([w2*10,np.abs(f2)]).T,fmt='%5.0f %8.4f')

w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/astrodon_gen2_filtre_i.txt',unpack=True)
idx   = np.argsort(w2)
w2 = np.array(w2)[idx]
f2 = np.array(f2)[idx]
np.savetxt('APOExptime/data/spm2_1m/Opticam/iprime_filter.data',np.array([w2*10,np.abs(f2)]).T,fmt='%5.0f %8.4f')

w2,f2 = np.loadtxt('APOExptime/data/spm2_1m/Opticam/astrodon_gen2_filtre_z.txt',unpack=True)
idx   = np.argsort(w2)
w2 = np.array(w2)[idx]
f2 = np.array(f2)[idx]
np.savetxt('APOExptime/data/spm2_1m/Opticam/zprime_filter.data',np.array([w2*10,np.abs(f2)]).T,fmt='%5.0f %8.4f')

# %%
np.all(np.diff(w2) > 0)
# Out:
# True

# %%
w2[1:][ff == False]
# Out:
# array([], dtype=float64)
